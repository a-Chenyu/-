# %%
# %run train.ipynb
# %run visualize.ipynb 
import matplotlib.pyplot as plt
# 解决中文显示问题
plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei']  # 指定中文字体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示异常
if __name__ == "__main__":
    # 1. 训练模型（使用内置语料，无需外部文件）
    model = train_word2vec(corpus_path=None, model_path="models/word2vec.model")
    
    # 2. 选择要可视化的词（必须在语料中存在）
    target_words = ["数据", "模型", "代码", "Python", "人工智能", "学习", "可视化", "项目", "环境", "科学"]
    
    # 3. 执行可视化
    visualize_words(model_path="models/word2vec.model", words=target_words)
